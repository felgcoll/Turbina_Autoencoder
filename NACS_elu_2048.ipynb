# %%
import pandas as pd
import numpy as np
from datetime import datetime,timedelta
import torch
import torch.nn as nn
from torch import optim

import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader
from torch.utils.data.sampler import SubsetRandomSampler
import time
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
train=pd.read_csv('/content/drive/MyDrive/Train/TRAIN_.csv',header=0,index_col=None).iloc[:,1:]
test=pd.read_csv('/content/drive/MyDrive/Train/TEST_.csv',header=0,index_col=None).iloc[:,1:]
valid=pd.read_csv('/content/drive/MyDrive/Train/VAL_.csv',header=0,index_col=None).iloc[:,1:]

# %%
if torch.cuda.is_available(): 
    print('El dispositivo que se usará a partir de ahora es ' + torch.cuda.get_device_name(0))
    device = torch.device("cuda:0")
else:
    print('Tu equipo no cuenta con un dispositivo compatible con CUDA')
    device = torch.device("cpu")
# Out:
# El dispositivo que se usará a partir de ahora es Tesla T4

# %%
train_on_gpu = torch.cuda.is_available()

if not train_on_gpu:
    print('CUDA is not available.  Training on CPU ...')
else:
    print('CUDA is available!  Training on GPU ...')
# Out:
# CUDA is available!  Training on GPU ...

# %%
torch.cuda.current_device()
# Out:
# 0

# %%
torch.backends.cudnn.enables = False

# %%
seed = 10
torch.manual_seed(seed)

# %%
train.shape, valid.shape, test.shape
# Out:
# ((396408, 24), (158563, 24), (105709, 24))

# %%
df_train_np = np.stack([train[col].values for col in train], 1)
df_train_tensor = torch.tensor(df_train_np, dtype=torch.float)
df_train_tensor[0]
# Out:
# tensor([0.5365, 0.4831, 0.5028, 0.5017, 0.5550, 0.4956, 0.3937, 0.4715, 0.4859,
#         0.4867, 0.4588, 0.4819, 0.4761, 0.5949, 0.5108, 0.5747, 0.5116, 0.4501,
#         0.5572, 0.5252, 0.4692, 0.4934, 0.5095, 0.5421])

# %%
outputs_train_tensor = df_train_tensor

# %%
df_valid_np = np.stack([valid[col].values for col in valid], 1)
df_valid_tensor = torch.tensor(df_valid_np, dtype=torch.float)
df_valid_tensor[0]
# Out:
# tensor([0.4978, 0.4407, 0.3947, 0.4975, 0.4825, 0.4603, 0.4598, 0.3547, 0.5107,
#         0.4583, 0.4971, 0.5065, 0.5015, 0.5493, 0.3980, 0.4780, 0.5112, 0.5351,
#         0.4524, 0.4575, 0.3774, 0.5181, 0.4494, 0.3912])

# %%
outputs_valid_tensor = df_valid_tensor

# %%
train_data = TensorDataset(df_train_tensor, outputs_train_tensor)
valid_data = TensorDataset(df_valid_tensor, outputs_valid_tensor)

# %%
batch_size = 2048
train_loader = DataLoader(train_data, batch_size, shuffle=False)
valid_loader = DataLoader(valid_data, batch_size, shuffle=False)

# %%
col = 24

class Classifier(nn.Module):
    def __init__(self):
        super().__init__()
        self.fc1 = nn.Linear(col, int(col/2))
        self.fc2 = nn.Linear(int(col/2), col)

    def forward(self, x):
        x = x.view(x.shape[0], -1)
        
        x = F.elu(self.fc1(x))
        x = self.fc2(x)
        
        return x

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = Classifier()
torch.cuda.current_device()
# Out:
# 0

# %%
criterion = torch.nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001, betas=(0.9, 0.999), eps=1e-08, weight_decay=0, amsgrad=False) #betas #eps #weight_decay #amsgrad
model.to(device);

n_epochs = 500
valid_loss_min = np.Inf # track change in validation loss
train_losses, test_losses, accuracy_losses = [], [], []
start = time.process_time()
for epoch in range(1, n_epochs+1):

    # keep track of training and validation loss
    train_loss = 0.0
    valid_loss = 0.0
    
    ###################
    # train the model #
    ###################
    model.train()
    for data, target in train_loader:
        # move tensors to GPU if CUDA is available
        if train_on_gpu:
            images, target = data.cuda(), target.cuda()
        # clear the gradients of all optimized variables
        optimizer.zero_grad()
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(images)
        # calculate the batch loss
        loss = criterion(output, images)
        # backward pass: compute gradient of the loss with respect to model parameters
        loss.backward()
        # perform a single optimization step (parameter update)
        optimizer.step()
        # update training loss
        train_loss += loss.item()*images.size(0)
        
    ######################    
    # validate the model #
    ######################
    model.eval()
    for data, target in valid_loader:
        # move tensors to GPU if CUDA is available
        if train_on_gpu:
            images, target = data.cuda(), target.cuda()
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(images)
        # calculate the batch loss
        loss = criterion(output, images)
        # update average validation loss 
        valid_loss += loss.item()*data.size(0)
    
    # calculate average losses
    train_loss = train_loss/len(train_loader.sampler)
    valid_loss = valid_loss/len(valid_loader.sampler)   
    train_losses.append(train_loss)
    test_losses.append(valid_loss)
    # print training/validation statistics 
    print('Epoch: {} \tTraining Loss: {:.10f} \tValidation Loss: {:.10f}'.format(
        epoch, train_loss, valid_loss))
    
    # save model if validation loss has decreased
    if valid_loss <= valid_loss_min:
        print('Validation loss decreased ({:.10f} --> {:.10f}).  Saving model ...'.format(
        valid_loss_min,
        valid_loss))
        torch.save(model.state_dict(), 'data_b16_lr0001.pt')
        valid_loss_min = valid_loss
        
print(time.process_time() - start)
# Out:
# Epoch: 1 	Training Loss: 0.0684419028 	Validation Loss: 0.0099905771
# Validation loss decreased (inf --> 0.0099905771).  Saving model ...
# Epoch: 2 	Training Loss: 0.0090879548 	Validation Loss: 0.0086399840
# Validation loss decreased (0.0099905771 --> 0.0086399840).  Saving model ...
# Epoch: 3 	Training Loss: 0.0075455411 	Validation Loss: 0.0070039430
# Validation loss decreased (0.0086399840 --> 0.0070039430).  Saving model ...
# Epoch: 4 	Training Loss: 0.0059715176 	Validation Loss: 0.0057964225
# Validation loss decreased (0.0070039430 --> 0.0057964225).  Saving model ...
# Epoch: 5 	Training Loss: 0.0050623691 	Validation Loss: 0.0051690994
# Validation loss decreased (0.0057964225 --> 0.0051690994).  Saving model ...
# Epoch: 6 	Training Loss: 0.0045372358 	Validation Loss: 0.0047486099
# Validation loss decreased (0.0051690994 --> 0.0047486099).  Saving model ...
# Epoch: 7 	Training Loss: 0.0041541980 	Validation Loss: 0.0044142870
# Validation loss decreased (0.0047486099 --> 0.0044142870).  Saving model ...
# Epoch: 8 	Training Loss: 0.0038526346 	Validation Loss: 0.0041373697
# Validation loss decreased (0.0044142870 --> 0.0041373697).  Saving model ...
# Epoch: 9 	Training Loss: 0.0036069878 	Validation Loss: 0.0039025701
# Validation loss decreased (0.0041373697 --> 0.0039025701).  Saving model ...
# Epoch: 10 	Training Loss: 0.0033951511 	Validation Loss: 0.0036912966
# Validation loss decreased (0.0039025701 --> 0.0036912966).  Saving model ...
# Epoch: 11 	Training Loss: 0.0032033375 	Validation Loss: 0.0034946866
# Validation loss decreased (0.0036912966 --> 0.0034946866).  Saving model ...
# Epoch: 12 	Training Loss: 0.0030277292 	Validation Loss: 0.0033162882
# Validation loss decreased (0.0034946866 --> 0.0033162882).  Saving model ...
# Epoch: 13 	Training Loss: 0.0028674229 	Validation Loss: 0.0031557426
# Validation loss decreased (0.0033162882 --> 0.0031557426).  Saving model ...
# Epoch: 14 	Training Loss: 0.0027199385 	Validation Loss: 0.0030105717
# Validation loss decreased (0.0031557426 --> 0.0030105717).  Saving model ...
# Epoch: 15 	Training Loss: 0.0025829334 	Validation Loss: 0.0028762772
# Validation loss decreased (0.0030105717 --> 0.0028762772).  Saving model ...
# Epoch: 16 	Training Loss: 0.0024560681 	Validation Loss: 0.0027497392
# Validation loss decreased (0.0028762772 --> 0.0027497392).  Saving model ...
# Epoch: 17 	Training Loss: 0.0023404311 	Validation Loss: 0.0026307096
# Validation loss decreased (0.0027497392 --> 0.0026307096).  Saving model ...
# Epoch: 18 	Training Loss: 0.0022372654 	Validation Loss: 0.0025207404
# Validation loss decreased (0.0026307096 --> 0.0025207404).  Saving model ...
# Epoch: 19 	Training Loss: 0.0021472349 	Validation Loss: 0.0024205963
# Validation loss decreased (0.0025207404 --> 0.0024205963).  Saving model ...
# Epoch: 20 	Training Loss: 0.0020698818 	Validation Loss: 0.0023299081
# Validation loss decreased (0.0024205963 --> 0.0023299081).  Saving model ...
# Epoch: 21 	Training Loss: 0.0020033378 	Validation Loss: 0.0022513026
# Validation loss decreased (0.0023299081 --> 0.0022513026).  Saving model ...
# Epoch: 22 	Training Loss: 0.0019446669 	Validation Loss: 0.0021836485
# Validation loss decreased (0.0022513026 --> 0.0021836485).  Saving model ...
# Epoch: 23 	Training Loss: 0.0018907491 	Validation Loss: 0.0021205223
# Validation loss decreased (0.0021836485 --> 0.0021205223).  Saving model ...
# Epoch: 24 	Training Loss: 0.0018390325 	Validation Loss: 0.0020602242
# Validation loss decreased (0.0021205223 --> 0.0020602242).  Saving model ...
# Epoch: 25 	Training Loss: 0.0017882440 	Validation Loss: 0.0020042849
# Validation loss decreased (0.0020602242 --> 0.0020042849).  Saving model ...
# Epoch: 26 	Training Loss: 0.0017390156 	Validation Loss: 0.0019535301
# Validation loss decreased (0.0020042849 --> 0.0019535301).  Saving model ...
# Epoch: 27 	Training Loss: 0.0016935556 	Validation Loss: 0.0019075127
# Validation loss decreased (0.0019535301 --> 0.0019075127).  Saving model ...
# Epoch: 28 	Training Loss: 0.0016543435 	Validation Loss: 0.0018673272
# Validation loss decreased (0.0019075127 --> 0.0018673272).  Saving model ...
# Epoch: 29 	Training Loss: 0.0016226160 	Validation Loss: 0.0018359725
# Validation loss decreased (0.0018673272 --> 0.0018359725).  Saving model ...
# Epoch: 30 	Training Loss: 0.0015978140 	Validation Loss: 0.0018118816
# Validation loss decreased (0.0018359725 --> 0.0018118816).  Saving model ...
# Epoch: 31 	Training Loss: 0.0015784075 	Validation Loss: 0.0017930066
# Validation loss decreased (0.0018118816 --> 0.0017930066).  Saving model ...
# Epoch: 32 	Training Loss: 0.0015628450 	Validation Loss: 0.0017778986
# Validation loss decreased (0.0017930066 --> 0.0017778986).  Saving model ...
# Epoch: 33 	Training Loss: 0.0015499701 	Validation Loss: 0.0017653441
# Validation loss decreased (0.0017778986 --> 0.0017653441).  Saving model ...
# Epoch: 34 	Training Loss: 0.0015390030 	Validation Loss: 0.0017546242
# Validation loss decreased (0.0017653441 --> 0.0017546242).  Saving model ...
# Epoch: 35 	Training Loss: 0.0015294258 	Validation Loss: 0.0017455397
# Validation loss decreased (0.0017546242 --> 0.0017455397).  Saving model ...
# Epoch: 36 	Training Loss: 0.0015209419 	Validation Loss: 0.0017381494
# Validation loss decreased (0.0017455397 --> 0.0017381494).  Saving model ...
# Epoch: 37 	Training Loss: 0.0015134697 	Validation Loss: 0.0017324190
# Validation loss decreased (0.0017381494 --> 0.0017324190).  Saving model ...
# Epoch: 38 	Training Loss: 0.0015069654 	Validation Loss: 0.0017283241
# Validation loss decreased (0.0017324190 --> 0.0017283241).  Saving model ...
# Epoch: 39 	Training Loss: 0.0015012949 	Validation Loss: 0.0017258516
# Validation loss decreased (0.0017283241 --> 0.0017258516).  Saving model ...
# Epoch: 40 	Training Loss: 0.0014962873 	Validation Loss: 0.0017245982
# Validation loss decreased (0.0017258516 --> 0.0017245982).  Saving model ...
# Epoch: 41 	Training Loss: 0.0014917773 	Validation Loss: 0.0017241185
# Validation loss decreased (0.0017245982 --> 0.0017241185).  Saving model ...
# Epoch: 42 	Training Loss: 0.0014876501 	Validation Loss: 0.0017244080
# Epoch: 43 	Training Loss: 0.0014838500 	Validation Loss: 0.0017254753
# Epoch: 44 	Training Loss: 0.0014803239 	Validation Loss: 0.0017273176
# Epoch: 45 	Training Loss: 0.0014770305 	Validation Loss: 0.0017299947
# Epoch: 46 	Training Loss: 0.0014740281 	Validation Loss: 0.0017334180
# Epoch: 47 	Training Loss: 0.0014713926 	Validation Loss: 0.0017374743
# Epoch: 48 	Training Loss: 0.0014690644 	Validation Loss: 0.0017420374
# Epoch: 49 	Training Loss: 0.0014669359 	Validation Loss: 0.0017467873
# Epoch: 50 	Training Loss: 0.0014649413 	Validation Loss: 0.0017516410
# Epoch: 51 	Training Loss: 0.0014630837 	Validation Loss: 0.0017565681
# Epoch: 52 	Training Loss: 0.0014613706 	Validation Loss: 0.0017615031
# Epoch: 53 	Training Loss: 0.0014597947 	Validation Loss: 0.0017663776
# Epoch: 54 	Training Loss: 0.0014583450 	Validation Loss: 0.0017711424
# Epoch: 55 	Training Loss: 0.0014570103 	Validation Loss: 0.0017757661
# Epoch: 56 	Training Loss: 0.0014557791 	Validation Loss: 0.0017802321
# Epoch: 57 	Training Loss: 0.0014546377 	Validation Loss: 0.0017845354
# Epoch: 58 	Training Loss: 0.0014535671 	Validation Loss: 0.0017886901
# Epoch: 59 	Training Loss: 0.0014525331 	Validation Loss: 0.0017927544
# Epoch: 60 	Training Loss: 0.0014514756 	Validation Loss: 0.0017967274
# Epoch: 61 	Training Loss: 0.0014504056 	Validation Loss: 0.0018003407
# Epoch: 62 	Training Loss: 0.0014494851 	Validation Loss: 0.0018040274
# Epoch: 63 	Training Loss: 0.0014487347 	Validation Loss: 0.0018077194
# Epoch: 64 	Training Loss: 0.0014481107 	Validation Loss: 0.0018112613
# Epoch: 65 	Training Loss: 0.0014475669 	Validation Loss: 0.0018146641
# Epoch: 66 	Training Loss: 0.0014470631 	Validation Loss: 0.0018179225
# Epoch: 67 	Training Loss: 0.0014465377 	Validation Loss: 0.0018209893
# Epoch: 68 	Training Loss: 0.0014460217 	Validation Loss: 0.0018238758
# Epoch: 69 	Training Loss: 0.0014455344 	Validation Loss: 0.0018265776
# Epoch: 70 	Training Loss: 0.0014450748 	Validation Loss: 0.0018290956
# Epoch: 71 	Training Loss: 0.0014446420 	Validation Loss: 0.0018314368
# Epoch: 72 	Training Loss: 0.0014442302 	Validation Loss: 0.0018336096
# Epoch: 73 	Training Loss: 0.0014438308 	Validation Loss: 0.0018356258
# Epoch: 74 	Training Loss: 0.0014434299 	Validation Loss: 0.0018375303
# Epoch: 75 	Training Loss: 0.0014429944 	Validation Loss: 0.0018393787
# Epoch: 76 	Training Loss: 0.0014425247 	Validation Loss: 0.0018409616
# Epoch: 77 	Training Loss: 0.0014421362 	Validation Loss: 0.0018424529
# Epoch: 78 	Training Loss: 0.0014418124 	Validation Loss: 0.0018439737
# Epoch: 79 	Training Loss: 0.0014415055 	Validation Loss: 0.0018454152
# Epoch: 80 	Training Loss: 0.0014412027 	Validation Loss: 0.0018466530
# Epoch: 81 	Training Loss: 0.0014409734 	Validation Loss: 0.0018478746
# Epoch: 82 	Training Loss: 0.0014407216 	Validation Loss: 0.0018490033
# Epoch: 83 	Training Loss: 0.0014404515 	Validation Loss: 0.0018500603
# Epoch: 84 	Training Loss: 0.0014401804 	Validation Loss: 0.0018510571
# Epoch: 85 	Training Loss: 0.0014399111 	Validation Loss: 0.0018519978
# Epoch: 86 	Training Loss: 0.0014396508 	Validation Loss: 0.0018528676
# Epoch: 87 	Training Loss: 0.0014394101 	Validation Loss: 0.0018536738
# Epoch: 88 	Training Loss: 0.0014391818 	Validation Loss: 0.0018544520
# Epoch: 89 	Training Loss: 0.0014389491 	Validation Loss: 0.0018551655
# Epoch: 90 	Training Loss: 0.0014387132 	Validation Loss: 0.0018558057
# Epoch: 91 	Training Loss: 0.0014384818 	Validation Loss: 0.0018564039
# Epoch: 92 	Training Loss: 0.0014382541 	Validation Loss: 0.0018570017
# Epoch: 93 	Training Loss: 0.0014380266 	Validation Loss: 0.0018576352
# Epoch: 94 	Training Loss: 0.0014377964 	Validation Loss: 0.0018582271
# Epoch: 95 	Training Loss: 0.0014375679 	Validation Loss: 0.0018584756
# Epoch: 96 	Training Loss: 0.0014373503 	Validation Loss: 0.0018584799
# Epoch: 97 	Training Loss: 0.0014371279 	Validation Loss: 0.0018586154
# Epoch: 98 	Training Loss: 0.0014369110 	Validation Loss: 0.0018591623
# Epoch: 99 	Training Loss: 0.0014367364 	Validation Loss: 0.0018595182
# Epoch: 100 	Training Loss: 0.0014365604 	Validation Loss: 0.0018597062
# Epoch: 101 	Training Loss: 0.0014363704 	Validation Loss: 0.0018598677
# Epoch: 102 	Training Loss: 0.0014361771 	Validation Loss: 0.0018600266
# Epoch: 103 	Training Loss: 0.0014359839 	Validation Loss: 0.0018601799
# Epoch: 104 	Training Loss: 0.0014357917 	Validation Loss: 0.0018603256
# Epoch: 105 	Training Loss: 0.0014356007 	Validation Loss: 0.0018604628
# Epoch: 106 	Training Loss: 0.0014354109 	Validation Loss: 0.0018605921
# Epoch: 107 	Training Loss: 0.0014352222 	Validation Loss: 0.0018607125
# Epoch: 108 	Training Loss: 0.0014350346 	Validation Loss: 0.0018608249
# Epoch: 109 	Training Loss: 0.0014348481 	Validation Loss: 0.0018609295
# Epoch: 110 	Training Loss: 0.0014346627 	Validation Loss: 0.0018610263
# Epoch: 111 	Training Loss: 0.0014344783 	Validation Loss: 0.0018611156
# Epoch: 112 	Training Loss: 0.0014342947 	Validation Loss: 0.0018611986
# Epoch: 113 	Training Loss: 0.0014341120 	Validation Loss: 0.0018612747
# Epoch: 114 	Training Loss: 0.0014339302 	Validation Loss: 0.0018613445
# Epoch: 115 	Training Loss: 0.0014337491 	Validation Loss: 0.0018614091
# Epoch: 116 	Training Loss: 0.0014335688 	Validation Loss: 0.0018614680
# Epoch: 117 	Training Loss: 0.0014333893 	Validation Loss: 0.0018615222
# Epoch: 118 	Training Loss: 0.0014332105 	Validation Loss: 0.0018615719
# Epoch: 119 	Training Loss: 0.0014330323 	Validation Loss: 0.0018616174
# Epoch: 120 	Training Loss: 0.0014328548 	Validation Loss: 0.0018616603
# Epoch: 121 	Training Loss: 0.0014326779 	Validation Loss: 0.0018617003
# Epoch: 122 	Training Loss: 0.0014325016 	Validation Loss: 0.0018617376
# Epoch: 123 	Training Loss: 0.0014323260 	Validation Loss: 0.0018617730
# Epoch: 124 	Training Loss: 0.0014321508 	Validation Loss: 0.0018618064
# Epoch: 125 	Training Loss: 0.0014319763 	Validation Loss: 0.0018618390
# Epoch: 126 	Training Loss: 0.0014318022 	Validation Loss: 0.0018618711
# Epoch: 127 	Training Loss: 0.0014316288 	Validation Loss: 0.0018619028
# Epoch: 128 	Training Loss: 0.0014314559 	Validation Loss: 0.0018619347
# Epoch: 129 	Training Loss: 0.0014312835 	Validation Loss: 0.0018619670
# Epoch: 130 	Training Loss: 0.0014311119 	Validation Loss: 0.0018620000
# Epoch: 131 	Training Loss: 0.0014309409 	Validation Loss: 0.0018620333
# Epoch: 132 	Training Loss: 0.0014307707 	Validation Loss: 0.0018620665
# Epoch: 133 	Training Loss: 0.0014306012 	Validation Loss: 0.0018621005
# Epoch: 134 	Training Loss: 0.0014304326 	Validation Loss: 0.0018621332
# Epoch: 135 	Training Loss: 0.0014302649 	Validation Loss: 0.0018621649
# Epoch: 136 	Training Loss: 0.0014300980 	Validation Loss: 0.0018621929
# Epoch: 137 	Training Loss: 0.0014299318 	Validation Loss: 0.0018622167
# Epoch: 138 	Training Loss: 0.0014297662 	Validation Loss: 0.0018622350
# Epoch: 139 	Training Loss: 0.0014296010 	Validation Loss: 0.0018622449
# Epoch: 140 	Training Loss: 0.0014294360 	Validation Loss: 0.0018622457
# Epoch: 141 	Training Loss: 0.0014292708 	Validation Loss: 0.0018622433
# Epoch: 142 	Training Loss: 0.0014291053 	Validation Loss: 0.0018622663
# Epoch: 143 	Training Loss: 0.0014289415 	Validation Loss: 0.0018623764
# Epoch: 144 	Training Loss: 0.0014287837 	Validation Loss: 0.0018625756
# Epoch: 145 	Training Loss: 0.0014286303 	Validation Loss: 0.0018627422
# Epoch: 146 	Training Loss: 0.0014284744 	Validation Loss: 0.0018628489
# Epoch: 147 	Training Loss: 0.0014283166 	Validation Loss: 0.0018629346
# Epoch: 148 	Training Loss: 0.0014281590 	Validation Loss: 0.0018630167
# Epoch: 149 	Training Loss: 0.0014280023 	Validation Loss: 0.0018630982
# Epoch: 150 	Training Loss: 0.0014278466 	Validation Loss: 0.0018631809
# Epoch: 151 	Training Loss: 0.0014276919 	Validation Loss: 0.0018632639
# Epoch: 152 	Training Loss: 0.0014275381 	Validation Loss: 0.0018633478
# Epoch: 153 	Training Loss: 0.0014273854 	Validation Loss: 0.0018634323
# Epoch: 154 	Training Loss: 0.0014272337 	Validation Loss: 0.0018635171
# Epoch: 155 	Training Loss: 0.0014270831 	Validation Loss: 0.0018636025
# Epoch: 156 	Training Loss: 0.0014269336 	Validation Loss: 0.0018636883
# Epoch: 157 	Training Loss: 0.0014267851 	Validation Loss: 0.0018637741
# Epoch: 158 	Training Loss: 0.0014266377 	Validation Loss: 0.0018638602
# Epoch: 159 	Training Loss: 0.0014264914 	Validation Loss: 0.0018639462
# Epoch: 160 	Training Loss: 0.0014263463 	Validation Loss: 0.0018640316
# Epoch: 161 	Training Loss: 0.0014262024 	Validation Loss: 0.0018641176
# Epoch: 162 	Training Loss: 0.0014260596 	Validation Loss: 0.0018642021
# Epoch: 163 	Training Loss: 0.0014259180 	Validation Loss: 0.0018642868
# Epoch: 164 	Training Loss: 0.0014257777 	Validation Loss: 0.0018643706
# Epoch: 165 	Training Loss: 0.0014256385 	Validation Loss: 0.0018644534
# Epoch: 166 	Training Loss: 0.0014255006 	Validation Loss: 0.0018645360
# Epoch: 167 	Training Loss: 0.0014253640 	Validation Loss: 0.0018646168
# Epoch: 168 	Training Loss: 0.0014252285 	Validation Loss: 0.0018646965
# Epoch: 169 	Training Loss: 0.0014250944 	Validation Loss: 0.0018647747
# Epoch: 170 	Training Loss: 0.0014249616 	Validation Loss: 0.0018648523
# Epoch: 171 	Training Loss: 0.0014248301 	Validation Loss: 0.0018649274
# Epoch: 172 	Training Loss: 0.0014246999 	Validation Loss: 0.0018650021
# Epoch: 173 	Training Loss: 0.0014245710 	Validation Loss: 0.0018650752
# Epoch: 174 	Training Loss: 0.0014244434 	Validation Loss: 0.0018651462
# Epoch: 175 	Training Loss: 0.0014243171 	Validation Loss: 0.0018652154
# Epoch: 176 	Training Loss: 0.0014241922 	Validation Loss: 0.0018652832
# Epoch: 177 	Training Loss: 0.0014240685 	Validation Loss: 0.0018653498
# Epoch: 178 	Training Loss: 0.0014239463 	Validation Loss: 0.0018654130
# Epoch: 179 	Training Loss: 0.0014238253 	Validation Loss: 0.0018654752
# Epoch: 180 	Training Loss: 0.0014237057 	Validation Loss: 0.0018655355
# Epoch: 181 	Training Loss: 0.0014235874 	Validation Loss: 0.0018655939
# Epoch: 182 	Training Loss: 0.0014234704 	Validation Loss: 0.0018656500
# Epoch: 183 	Training Loss: 0.0014233548 	Validation Loss: 0.0018657043
# Epoch: 184 	Training Loss: 0.0014232405 	Validation Loss: 0.0018657567
# Epoch: 185 	Training Loss: 0.0014231275 	Validation Loss: 0.0018658072
# Epoch: 186 	Training Loss: 0.0014230158 	Validation Loss: 0.0018658547
# Epoch: 187 	Training Loss: 0.0014229054 	Validation Loss: 0.0018659012
# Epoch: 188 	Training Loss: 0.0014227964 	Validation Loss: 0.0018659452
# Epoch: 189 	Training Loss: 0.0014226886 	Validation Loss: 0.0018659879
# Epoch: 190 	Training Loss: 0.0014225821 	Validation Loss: 0.0018660274
# Epoch: 191 	Training Loss: 0.0014224767 	Validation Loss: 0.0018660664
# Epoch: 192 	Training Loss: 0.0014223728 	Validation Loss: 0.0018661019
# Epoch: 193 	Training Loss: 0.0014222700 	Validation Loss: 0.0018661370
# Epoch: 194 	Training Loss: 0.0014221686 	Validation Loss: 0.0018661698
# Epoch: 195 	Training Loss: 0.0014220682 	Validation Loss: 0.0018662006
# Epoch: 196 	Training Loss: 0.0014219692 	Validation Loss: 0.0018662294
# Epoch: 197 	Training Loss: 0.0014218712 	Validation Loss: 0.0018662569
# Epoch: 198 	Training Loss: 0.0014217745 	Validation Loss: 0.0018662825
# Epoch: 199 	Training Loss: 0.0014216790 	Validation Loss: 0.0018663068
# Epoch: 200 	Training Loss: 0.0014215846 	Validation Loss: 0.0018663296
# Epoch: 201 	Training Loss: 0.0014214913 	Validation Loss: 0.0018663510
# Epoch: 202 	Training Loss: 0.0014213991 	Validation Loss: 0.0018663709
# Epoch: 203 	Training Loss: 0.0014213081 	Validation Loss: 0.0018663892
# Epoch: 204 	Training Loss: 0.0014212181 	Validation Loss: 0.0018664068
# Epoch: 205 	Training Loss: 0.0014211292 	Validation Loss: 0.0018664224
# Epoch: 206 	Training Loss: 0.0014210414 	Validation Loss: 0.0018664379
# Epoch: 207 	Training Loss: 0.0014209546 	Validation Loss: 0.0018664506
# Epoch: 208 	Training Loss: 0.0014208688 	Validation Loss: 0.0018664637
# Epoch: 209 	Training Loss: 0.0014207840 	Validation Loss: 0.0018664759
# Epoch: 210 	Training Loss: 0.0014207002 	Validation Loss: 0.0018664867
# Epoch: 211 	Training Loss: 0.0014206175 	Validation Loss: 0.0018664971
# Epoch: 212 	Training Loss: 0.0014205356 	Validation Loss: 0.0018665060
# Epoch: 213 	Training Loss: 0.0014204547 	Validation Loss: 0.0018665147
# Epoch: 214 	Training Loss: 0.0014203747 	Validation Loss: 0.0018665230
# Epoch: 215 	Training Loss: 0.0014202957 	Validation Loss: 0.0018665309
# Epoch: 216 	Training Loss: 0.0014202175 	Validation Loss: 0.0018665382
# Epoch: 217 	Training Loss: 0.0014201402 	Validation Loss: 0.0018665460
# Epoch: 218 	Training Loss: 0.0014200638 	Validation Loss: 0.0018665524
# Epoch: 219 	Training Loss: 0.0014199882 	Validation Loss: 0.0018665590
# Epoch: 220 	Training Loss: 0.0014199134 	Validation Loss: 0.0018665654
# Epoch: 221 	Training Loss: 0.0014198395 	Validation Loss: 0.0018665720
# Epoch: 222 	Training Loss: 0.0014197663 	Validation Loss: 0.0018665788
# Epoch: 223 	Training Loss: 0.0014196940 	Validation Loss: 0.0018665857
# Epoch: 224 	Training Loss: 0.0014196223 	Validation Loss: 0.0018665927
# Epoch: 225 	Training Loss: 0.0014195515 	Validation Loss: 0.0018666003
# Epoch: 226 	Training Loss: 0.0014194814 	Validation Loss: 0.0018666082
# Epoch: 227 	Training Loss: 0.0014194119 	Validation Loss: 0.0018666174
# Epoch: 228 	Training Loss: 0.0014193431 	Validation Loss: 0.0018666267
# Epoch: 229 	Training Loss: 0.0014192750 	Validation Loss: 0.0018666374
# Epoch: 230 	Training Loss: 0.0014192075 	Validation Loss: 0.0018666486
# Epoch: 231 	Training Loss: 0.0014191406 	Validation Loss: 0.0018666618
# Epoch: 232 	Training Loss: 0.0014190741 	Validation Loss: 0.0018666775
# Epoch: 233 	Training Loss: 0.0014190080 	Validation Loss: 0.0018666949
# Epoch: 234 	Training Loss: 0.0014189421 	Validation Loss: 0.0018667158
# Epoch: 235 	Training Loss: 0.0014188761 	Validation Loss: 0.0018667422
# Epoch: 236 	Training Loss: 0.0014188094 	Validation Loss: 0.0018667769
# Epoch: 237 	Training Loss: 0.0014187409 	Validation Loss: 0.0018668245
# Epoch: 238 	Training Loss: 0.0014186685 	Validation Loss: 0.0018668890
# Epoch: 239 	Training Loss: 0.0014185884 	Validation Loss: 0.0018669705
# Epoch: 240 	Training Loss: 0.0014184987 	Validation Loss: 0.0018670471
# Epoch: 241 	Training Loss: 0.0014184099 	Validation Loss: 0.0018671243
# Epoch: 242 	Training Loss: 0.0014183379 	Validation Loss: 0.0018672111
# Epoch: 243 	Training Loss: 0.0014182831 	Validation Loss: 0.0018672905
# Epoch: 244 	Training Loss: 0.0014182367 	Validation Loss: 0.0018673551
# Epoch: 245 	Training Loss: 0.0014181797 	Validation Loss: 0.0018673700
# Epoch: 246 	Training Loss: 0.0014181156 	Validation Loss: 0.0018673753
# Epoch: 247 	Training Loss: 0.0014180564 	Validation Loss: 0.0018673835
# Epoch: 248 	Training Loss: 0.0014180019 	Validation Loss: 0.0018673805
# Epoch: 249 	Training Loss: 0.0014179473 	Validation Loss: 0.0018673728
# Epoch: 250 	Training Loss: 0.0014178915 	Validation Loss: 0.0018673673
# Epoch: 251 	Training Loss: 0.0014178346 	Validation Loss: 0.0018673658
# Epoch: 252 	Training Loss: 0.0014177773 	Validation Loss: 0.0018673671
# Epoch: 253 	Training Loss: 0.0014177200 	Validation Loss: 0.0018673701
# Epoch: 254 	Training Loss: 0.0014176629 	Validation Loss: 0.0018673751
# Epoch: 255 	Training Loss: 0.0014176061 	Validation Loss: 0.0018673816
# Epoch: 256 	Training Loss: 0.0014175497 	Validation Loss: 0.0018673891
# Epoch: 257 	Training Loss: 0.0014174938 	Validation Loss: 0.0018673977
# Epoch: 258 	Training Loss: 0.0014174384 	Validation Loss: 0.0018674086
# Epoch: 259 	Training Loss: 0.0014173836 	Validation Loss: 0.0018674197
# Epoch: 260 	Training Loss: 0.0014173293 	Validation Loss: 0.0018674332
# Epoch: 261 	Training Loss: 0.0014172755 	Validation Loss: 0.0018674465
# Epoch: 262 	Training Loss: 0.0014172223 	Validation Loss: 0.0018674625
# Epoch: 263 	Training Loss: 0.0014171697 	Validation Loss: 0.0018674781
# Epoch: 264 	Training Loss: 0.0014171177 	Validation Loss: 0.0018674955
# Epoch: 265 	Training Loss: 0.0014170663 	Validation Loss: 0.0018675136
# Epoch: 266 	Training Loss: 0.0014170153 	Validation Loss: 0.0018675329
# Epoch: 267 	Training Loss: 0.0014169649 	Validation Loss: 0.0018675529
# Epoch: 268 	Training Loss: 0.0014169151 	Validation Loss: 0.0018675734
# Epoch: 269 	Training Loss: 0.0014168657 	Validation Loss: 0.0018675946
# Epoch: 270 	Training Loss: 0.0014168168 	Validation Loss: 0.0018676168
# Epoch: 271 	Training Loss: 0.0014167683 	Validation Loss: 0.0018676395
# Epoch: 272 	Training Loss: 0.0014167203 	Validation Loss: 0.0018676622
# Epoch: 273 	Training Loss: 0.0014166728 	Validation Loss: 0.0018676865
# Epoch: 274 	Training Loss: 0.0014166256 	Validation Loss: 0.0018677111
# Epoch: 275 	Training Loss: 0.0014165789 	Validation Loss: 0.0018677354
# Epoch: 276 	Training Loss: 0.0014165325 	Validation Loss: 0.0018677617
# Epoch: 277 	Training Loss: 0.0014164865 	Validation Loss: 0.0018677877
# Epoch: 278 	Training Loss: 0.0014164409 	Validation Loss: 0.0018678146
# Epoch: 279 	Training Loss: 0.0014163957 	Validation Loss: 0.0018678422
# Epoch: 280 	Training Loss: 0.0014163508 	Validation Loss: 0.0018678698
# Epoch: 281 	Training Loss: 0.0014163063 	Validation Loss: 0.0018678979
# Epoch: 282 	Training Loss: 0.0014162621 	Validation Loss: 0.0018679271
# Epoch: 283 	Training Loss: 0.0014162182 	Validation Loss: 0.0018679563
# Epoch: 284 	Training Loss: 0.0014161747 	Validation Loss: 0.0018679867
# Epoch: 285 	Training Loss: 0.0014161315 	Validation Loss: 0.0018680167
# Epoch: 286 	Training Loss: 0.0014160886 	Validation Loss: 0.0018680483
# Epoch: 287 	Training Loss: 0.0014160460 	Validation Loss: 0.0018680796
# Epoch: 288 	Training Loss: 0.0014160037 	Validation Loss: 0.0018681116
# Epoch: 289 	Training Loss: 0.0014159618 	Validation Loss: 0.0018681441
# Epoch: 290 	Training Loss: 0.0014159201 	Validation Loss: 0.0018681775
# Epoch: 291 	Training Loss: 0.0014158787 	Validation Loss: 0.0018682108
# Epoch: 292 	Training Loss: 0.0014158376 	Validation Loss: 0.0018682441
# Epoch: 293 	Training Loss: 0.0014157968 	Validation Loss: 0.0018682788
# Epoch: 294 	Training Loss: 0.0014157562 	Validation Loss: 0.0018683140
# Epoch: 295 	Training Loss: 0.0014157159 	Validation Loss: 0.0018683493
# Epoch: 296 	Training Loss: 0.0014156759 	Validation Loss: 0.0018683846
# Epoch: 297 	Training Loss: 0.0014156362 	Validation Loss: 0.0018684215
# Epoch: 298 	Training Loss: 0.0014155967 	Validation Loss: 0.0018684580
# Epoch: 299 	Training Loss: 0.0014155574 	Validation Loss: 0.0018684951
# Epoch: 300 	Training Loss: 0.0014155184 	Validation Loss: 0.0018685324
# Epoch: 301 	Training Loss: 0.0014154798 	Validation Loss: 0.0018685708
# Epoch: 302 	Training Loss: 0.0014154412 	Validation Loss: 0.0018686090
# Epoch: 303 	Training Loss: 0.0014154030 	Validation Loss: 0.0018686479
# Epoch: 304 	Training Loss: 0.0014153649 	Validation Loss: 0.0018686872
# Epoch: 305 	Training Loss: 0.0014153271 	Validation Loss: 0.0018687266
# Epoch: 306 	Training Loss: 0.0014152895 	Validation Loss: 0.0018687666
# Epoch: 307 	Training Loss: 0.0014152522 	Validation Loss: 0.0018688067
# Epoch: 308 	Training Loss: 0.0014152150 	Validation Loss: 0.0018688465
# Epoch: 309 	Training Loss: 0.0014151781 	Validation Loss: 0.0018688865
# Epoch: 310 	Training Loss: 0.0014151414 	Validation Loss: 0.0018689265
# Epoch: 311 	Training Loss: 0.0014151048 	Validation Loss: 0.0018689664
# Epoch: 312 	Training Loss: 0.0014150684 	Validation Loss: 0.0018690051
# Epoch: 313 	Training Loss: 0.0014150323 	Validation Loss: 0.0018690435
# Epoch: 314 	Training Loss: 0.0014149963 	Validation Loss: 0.0018690805
# Epoch: 315 	Training Loss: 0.0014149605 	Validation Loss: 0.0018691167
# Epoch: 316 	Training Loss: 0.0014149249 	Validation Loss: 0.0018691505
# Epoch: 317 	Training Loss: 0.0014148893 	Validation Loss: 0.0018691842
# Epoch: 318 	Training Loss: 0.0014148540 	Validation Loss: 0.0018692150
# Epoch: 319 	Training Loss: 0.0014148187 	Validation Loss: 0.0018692444
# Epoch: 320 	Training Loss: 0.0014147836 	Validation Loss: 0.0018692732
# Epoch: 321 	Training Loss: 0.0014147485 	Validation Loss: 0.0018693023
# Epoch: 322 	Training Loss: 0.0014147135 	Validation Loss: 0.0018693335
# Epoch: 323 	Training Loss: 0.0014146783 	Validation Loss: 0.0018693697
# Epoch: 324 	Training Loss: 0.0014146430 	Validation Loss: 0.0018694125
# Epoch: 325 	Training Loss: 0.0014146073 	Validation Loss: 0.0018694640
# Epoch: 326 	Training Loss: 0.0014145712 	Validation Loss: 0.0018695197
# Epoch: 327 	Training Loss: 0.0014145356 	Validation Loss: 0.0018695707
# Epoch: 328 	Training Loss: 0.0014145030 	Validation Loss: 0.0018696125
# Epoch: 329 	Training Loss: 0.0014144742 	Validation Loss: 0.0018696452
# Epoch: 330 	Training Loss: 0.0014144460 	Validation Loss: 0.0018696761
# Epoch: 331 	Training Loss: 0.0014144161 	Validation Loss: 0.0018697109
# Epoch: 332 	Training Loss: 0.0014143843 	Validation Loss: 0.0018697506
# Epoch: 333 	Training Loss: 0.0014143519 	Validation Loss: 0.0018697926
# Epoch: 334 	Training Loss: 0.0014143195 	Validation Loss: 0.0018698364
# Epoch: 335 	Training Loss: 0.0014142872 	Validation Loss: 0.0018698806
# Epoch: 336 	Training Loss: 0.0014142551 	Validation Loss: 0.0018699251
# Epoch: 337 	Training Loss: 0.0014142232 	Validation Loss: 0.0018699702
# Epoch: 338 	Training Loss: 0.0014141915 	Validation Loss: 0.0018700158
# Epoch: 339 	Training Loss: 0.0014141599 	Validation Loss: 0.0018700615
# Epoch: 340 	Training Loss: 0.0014141284 	Validation Loss: 0.0018701070
# Epoch: 341 	Training Loss: 0.0014140972 	Validation Loss: 0.0018701535
# Epoch: 342 	Training Loss: 0.0014140661 	Validation Loss: 0.0018702000
# Epoch: 343 	Training Loss: 0.0014140350 	Validation Loss: 0.0018702469
# Epoch: 344 	Training Loss: 0.0014140042 	Validation Loss: 0.0018702938
# Epoch: 345 	Training Loss: 0.0014139735 	Validation Loss: 0.0018703414
# Epoch: 346 	Training Loss: 0.0014139428 	Validation Loss: 0.0018703889
# Epoch: 347 	Training Loss: 0.0014139123 	Validation Loss: 0.0018704368
# Epoch: 348 	Training Loss: 0.0014138820 	Validation Loss: 0.0018704854
# Epoch: 349 	Training Loss: 0.0014138516 	Validation Loss: 0.0018705337
# Epoch: 350 	Training Loss: 0.0014138215 	Validation Loss: 0.0018705832
# Epoch: 351 	Training Loss: 0.0014137915 	Validation Loss: 0.0018706323
# Epoch: 352 	Training Loss: 0.0014137616 	Validation Loss: 0.0018706819
# Epoch: 353 	Training Loss: 0.0014137318 	Validation Loss: 0.0018707323
# Epoch: 354 	Training Loss: 0.0014137020 	Validation Loss: 0.0018707828
# Epoch: 355 	Training Loss: 0.0014136725 	Validation Loss: 0.0018708338
# Epoch: 356 	Training Loss: 0.0014136429 	Validation Loss: 0.0018708853
# Epoch: 357 	Training Loss: 0.0014136135 	Validation Loss: 0.0018709376
# Epoch: 358 	Training Loss: 0.0014135841 	Validation Loss: 0.0018709897
# Epoch: 359 	Training Loss: 0.0014135549 	Validation Loss: 0.0018710422
# Epoch: 360 	Training Loss: 0.0014135257 	Validation Loss: 0.0018710933
# Epoch: 361 	Training Loss: 0.0014134965 	Validation Loss: 0.0018711461
# Epoch: 362 	Training Loss: 0.0014134674 	Validation Loss: 0.0018711957
# Epoch: 363 	Training Loss: 0.0014134383 	Validation Loss: 0.0018712437
# Epoch: 364 	Training Loss: 0.0014134092 	Validation Loss: 0.0018712895
# Epoch: 365 	Training Loss: 0.0014133800 	Validation Loss: 0.0018713338
# Epoch: 366 	Training Loss: 0.0014133507 	Validation Loss: 0.0018713778
# Epoch: 367 	Training Loss: 0.0014133213 	Validation Loss: 0.0018714193
# Epoch: 368 	Training Loss: 0.0014132921 	Validation Loss: 0.0018714598
# Epoch: 369 	Training Loss: 0.0014132637 	Validation Loss: 0.0018714972
# Epoch: 370 	Training Loss: 0.0014132363 	Validation Loss: 0.0018715313
# Epoch: 371 	Training Loss: 0.0014132098 	Validation Loss: 0.0018715646
# Epoch: 372 	Training Loss: 0.0014131832 	Validation Loss: 0.0018715978
# Epoch: 373 	Training Loss: 0.0014131561 	Validation Loss: 0.0018716316
# Epoch: 374 	Training Loss: 0.0014131286 	Validation Loss: 0.0018716661
# Epoch: 375 	Training Loss: 0.0014131010 	Validation Loss: 0.0018717009
# Epoch: 376 	Training Loss: 0.0014130735 	Validation Loss: 0.0018717355
# Epoch: 377 	Training Loss: 0.0014130461 	Validation Loss: 0.0018717706
# Epoch: 378 	Training Loss: 0.0014130187 	Validation Loss: 0.0018718050
# Epoch: 379 	Training Loss: 0.0014129915 	Validation Loss: 0.0018718400
# Epoch: 380 	Training Loss: 0.0014129644 	Validation Loss: 0.0018718741
# Epoch: 381 	Training Loss: 0.0014129373 	Validation Loss: 0.0018719081
# Epoch: 382 	Training Loss: 0.0014129104 	Validation Loss: 0.0018719423
# Epoch: 383 	Training Loss: 0.0014128835 	Validation Loss: 0.0018719762
# Epoch: 384 	Training Loss: 0.0014128568 	Validation Loss: 0.0018720097
# Epoch: 385 	Training Loss: 0.0014128301 	Validation Loss: 0.0018720431
# Epoch: 386 	Training Loss: 0.0014128035 	Validation Loss: 0.0018720765
# Epoch: 387 	Training Loss: 0.0014127770 	Validation Loss: 0.0018721092
# Epoch: 388 	Training Loss: 0.0014127506 	Validation Loss: 0.0018721422
# Epoch: 389 	Training Loss: 0.0014127243 	Validation Loss: 0.0018721748
# Epoch: 390 	Training Loss: 0.0014126981 	Validation Loss: 0.0018722077
# Epoch: 391 	Training Loss: 0.0014126719 	Validation Loss: 0.0018722398
# Epoch: 392 	Training Loss: 0.0014126459 	Validation Loss: 0.0018722717
# Epoch: 393 	Training Loss: 0.0014126199 	Validation Loss: 0.0018723029
# Epoch: 394 	Training Loss: 0.0014125941 	Validation Loss: 0.0018723347
# Epoch: 395 	Training Loss: 0.0014125683 	Validation Loss: 0.0018723660
# Epoch: 396 	Training Loss: 0.0014125426 	Validation Loss: 0.0018723972
# Epoch: 397 	Training Loss: 0.0014125170 	Validation Loss: 0.0018724281
# Epoch: 398 	Training Loss: 0.0014124916 	Validation Loss: 0.0018724588
# Epoch: 399 	Training Loss: 0.0014124662 	Validation Loss: 0.0018724889
# Epoch: 400 	Training Loss: 0.0014124409 	Validation Loss: 0.0018725197
# Epoch: 401 	Training Loss: 0.0014124156 	Validation Loss: 0.0018725496
# Epoch: 402 	Training Loss: 0.0014123905 	Validation Loss: 0.0018725796
# Epoch: 403 	Training Loss: 0.0014123655 	Validation Loss: 0.0018726091
# Epoch: 404 	Training Loss: 0.0014123405 	Validation Loss: 0.0018726383
# Epoch: 405 	Training Loss: 0.0014123157 	Validation Loss: 0.0018726676
# Epoch: 406 	Training Loss: 0.0014122909 	Validation Loss: 0.0018726965
# Epoch: 407 	Training Loss: 0.0014122663 	Validation Loss: 0.0018727256
# Epoch: 408 	Training Loss: 0.0014122417 	Validation Loss: 0.0018727543
# Epoch: 409 	Training Loss: 0.0014122172 	Validation Loss: 0.0018727829
# Epoch: 410 	Training Loss: 0.0014121928 	Validation Loss: 0.0018728112
# Epoch: 411 	Training Loss: 0.0014121685 	Validation Loss: 0.0018728392
# Epoch: 412 	Training Loss: 0.0014121443 	Validation Loss: 0.0018728677
# Epoch: 413 	Training Loss: 0.0014121201 	Validation Loss: 0.0018728945
# Epoch: 414 	Training Loss: 0.0014120961 	Validation Loss: 0.0018729225
# Epoch: 415 	Training Loss: 0.0014120721 	Validation Loss: 0.0018729491
# Epoch: 416 	Training Loss: 0.0014120482 	Validation Loss: 0.0018729760
# Epoch: 417 	Training Loss: 0.0014120244 	Validation Loss: 0.0018730024
# Epoch: 418 	Training Loss: 0.0014120007 	Validation Loss: 0.0018730285
# Epoch: 419 	Training Loss: 0.0014119770 	Validation Loss: 0.0018730539
# Epoch: 420 	Training Loss: 0.0014119534 	Validation Loss: 0.0018730790
# Epoch: 421 	Training Loss: 0.0014119299 	Validation Loss: 0.0018731044
# Epoch: 422 	Training Loss: 0.0014119065 	Validation Loss: 0.0018731285
# Epoch: 423 	Training Loss: 0.0014118831 	Validation Loss: 0.0018731528
# Epoch: 424 	Training Loss: 0.0014118599 	Validation Loss: 0.0018731766
# Epoch: 425 	Training Loss: 0.0014118367 	Validation Loss: 0.0018731997
# Epoch: 426 	Training Loss: 0.0014118135 	Validation Loss: 0.0018732235
# Epoch: 427 	Training Loss: 0.0014117905 	Validation Loss: 0.0018732468
# Epoch: 428 	Training Loss: 0.0014117675 	Validation Loss: 0.0018732700
# Epoch: 429 	Training Loss: 0.0014117445 	Validation Loss: 0.0018732926
# Epoch: 430 	Training Loss: 0.0014117217 	Validation Loss: 0.0018733163
# Epoch: 431 	Training Loss: 0.0014116989 	Validation Loss: 0.0018733389
# Epoch: 432 	Training Loss: 0.0014116763 	Validation Loss: 0.0018733625
# Epoch: 433 	Training Loss: 0.0014116536 	Validation Loss: 0.0018733855
# Epoch: 434 	Training Loss: 0.0014116311 	Validation Loss: 0.0018734089
# Epoch: 435 	Training Loss: 0.0014116086 	Validation Loss: 0.0018734324
# Epoch: 436 	Training Loss: 0.0014115862 	Validation Loss: 0.0018734568
# Epoch: 437 	Training Loss: 0.0014115638 	Validation Loss: 0.0018734800
# Epoch: 438 	Training Loss: 0.0014115416 	Validation Loss: 0.0018735047
# Epoch: 439 	Training Loss: 0.0014115194 	Validation Loss: 0.0018735288
# Epoch: 440 	Training Loss: 0.0014114973 	Validation Loss: 0.0018735533
# Epoch: 441 	Training Loss: 0.0014114752 	Validation Loss: 0.0018735778
# Epoch: 442 	Training Loss: 0.0014114532 	Validation Loss: 0.0018736029
# Epoch: 443 	Training Loss: 0.0014114312 	Validation Loss: 0.0018736276
# Epoch: 444 	Training Loss: 0.0014114094 	Validation Loss: 0.0018736532
# Epoch: 445 	Training Loss: 0.0014113875 	Validation Loss: 0.0018736777
# Epoch: 446 	Training Loss: 0.0014113657 	Validation Loss: 0.0018737034
# Epoch: 447 	Training Loss: 0.0014113440 	Validation Loss: 0.0018737287
# Epoch: 448 	Training Loss: 0.0014113223 	Validation Loss: 0.0018737553
# Epoch: 449 	Training Loss: 0.0014113007 	Validation Loss: 0.0018737807
# Epoch: 450 	Training Loss: 0.0014112791 	Validation Loss: 0.0018738066
# Epoch: 451 	Training Loss: 0.0014112575 	Validation Loss: 0.0018738323
# Epoch: 452 	Training Loss: 0.0014112360 	Validation Loss: 0.0018738587
# Epoch: 453 	Training Loss: 0.0014112145 	Validation Loss: 0.0018738849
# Epoch: 454 	Training Loss: 0.0014111931 	Validation Loss: 0.0018739112
# Epoch: 455 	Training Loss: 0.0014111717 	Validation Loss: 0.0018739378
# Epoch: 456 	Training Loss: 0.0014111503 	Validation Loss: 0.0018739637
# Epoch: 457 	Training Loss: 0.0014111288 	Validation Loss: 0.0018739900
# Epoch: 458 	Training Loss: 0.0014111074 	Validation Loss: 0.0018740167
# Epoch: 459 	Training Loss: 0.0014110860 	Validation Loss: 0.0018740431
# Epoch: 460 	Training Loss: 0.0014110646 	Validation Loss: 0.0018740684
# Epoch: 461 	Training Loss: 0.0014110432 	Validation Loss: 0.0018740954
# Epoch: 462 	Training Loss: 0.0014110218 	Validation Loss: 0.0018741216
# Epoch: 463 	Training Loss: 0.0014110003 	Validation Loss: 0.0018741478
# Epoch: 464 	Training Loss: 0.0014109788 	Validation Loss: 0.0018741734
# Epoch: 465 	Training Loss: 0.0014109573 	Validation Loss: 0.0018741990
# Epoch: 466 	Training Loss: 0.0014109357 	Validation Loss: 0.0018742241
# Epoch: 467 	Training Loss: 0.0014109142 	Validation Loss: 0.0018742494
# Epoch: 468 	Training Loss: 0.0014108926 	Validation Loss: 0.0018742736
# Epoch: 469 	Training Loss: 0.0014108710 	Validation Loss: 0.0018742984
# Epoch: 470 	Training Loss: 0.0014108496 	Validation Loss: 0.0018743220
# Epoch: 471 	Training Loss: 0.0014108282 	Validation Loss: 0.0018743459
# Epoch: 472 	Training Loss: 0.0014108069 	Validation Loss: 0.0018743694
# Epoch: 473 	Training Loss: 0.0014107859 	Validation Loss: 0.0018743927
# Epoch: 474 	Training Loss: 0.0014107650 	Validation Loss: 0.0018744159
# Epoch: 475 	Training Loss: 0.0014107444 	Validation Loss: 0.0018744386
# Epoch: 476 	Training Loss: 0.0014107239 	Validation Loss: 0.0018744619
# Epoch: 477 	Training Loss: 0.0014107036 	Validation Loss: 0.0018744842
# Epoch: 478 	Training Loss: 0.0014106835 	Validation Loss: 0.0018745076
# Epoch: 479 	Training Loss: 0.0014106635 	Validation Loss: 0.0018745298
# Epoch: 480 	Training Loss: 0.0014106437 	Validation Loss: 0.0018745521
# Epoch: 481 	Training Loss: 0.0014106240 	Validation Loss: 0.0018745737
# Epoch: 482 	Training Loss: 0.0014106043 	Validation Loss: 0.0018745956
# Epoch: 483 	Training Loss: 0.0014105848 	Validation Loss: 0.0018746176
# Epoch: 484 	Training Loss: 0.0014105653 	Validation Loss: 0.0018746383
# Epoch: 485 	Training Loss: 0.0014105459 	Validation Loss: 0.0018746596
# Epoch: 486 	Training Loss: 0.0014105266 	Validation Loss: 0.0018746799
# Epoch: 487 	Training Loss: 0.0014105074 	Validation Loss: 0.0018747008
# Epoch: 488 	Training Loss: 0.0014104881 	Validation Loss: 0.0018747214
# Epoch: 489 	Training Loss: 0.0014104690 	Validation Loss: 0.0018747416
# Epoch: 490 	Training Loss: 0.0014104499 	Validation Loss: 0.0018747627
# Epoch: 491 	Training Loss: 0.0014104308 	Validation Loss: 0.0018747826
# Epoch: 492 	Training Loss: 0.0014104118 	Validation Loss: 0.0018748030
# Epoch: 493 	Training Loss: 0.0014103929 	Validation Loss: 0.0018748232
# Epoch: 494 	Training Loss: 0.0014103740 	Validation Loss: 0.0018748440
# Epoch: 495 	Training Loss: 0.0014103552 	Validation Loss: 0.0018748650
# Epoch: 496 	Training Loss: 0.0014103365 	Validation Loss: 0.0018748860
# Epoch: 497 	Training Loss: 0.0014103177 	Validation Loss: 0.0018749064
# Epoch: 498 	Training Loss: 0.0014102991 	Validation Loss: 0.0018749273
# Epoch: 499 	Training Loss: 0.0014102804 	Validation Loss: 0.0018749480
# Epoch: 500 	Training Loss: 0.0014102619 	Validation Loss: 0.0018749694
# 1916.427569684

# %%
plt.plot(train_losses, label='Training loss')
plt.plot(test_losses, label='Validation loss')
plt.legend(frameon=False)

# %%
dfrb = pd.read_csv('/content/drive/MyDrive/Train/RB_.csv').iloc[:,1:]
dfub = pd.read_csv('/content/drive/MyDrive/Train/UB_.csv').iloc[:,1:]
dfcdb = pd.read_csv('/content/drive/MyDrive/Train/CDB_.csv').iloc[:,1:]

# %%
test = pd.concat([test.iloc[:5000], dfrb.iloc[:5000], dfub.iloc[:5000], dfcdb.iloc[:5000]])

# %%
target = []
for i in range(0, 5000):
  target.append(1)

for i in range(0, 5000):
  target.append(2)

for i in range(0, 5000):
  target.append(3)

for i in range(0, 5000):
  target.append(4)

# %%
df_test_np = np.stack([test[col].values for col in test], 1)
df_test_tensor = torch.tensor(df_test_np, dtype=torch.float)
df_test_tensor[0]
# Out:
# tensor([0.4765, 0.5266, 0.4430, 0.3572, 0.4877, 0.4872, 0.5857, 0.4085, 0.3902,
#         0.5402, 0.4742, 0.3978, 0.4600, 0.5869, 0.5503, 0.3575, 0.4732, 0.5156,
#         0.3365, 0.4975, 0.4587, 0.3859, 0.4763, 0.4223])

# %%
model.eval()
# Out:
# Classifier(
#   (fc1): Linear(in_features=24, out_features=12, bias=True)
#   (fc2): Linear(in_features=12, out_features=24, bias=True)
# )

# %%
w=df_test_tensor
w=w.cuda()
log_ps = model(w)
log_ps
# Out:
# tensor([[0.4924, 0.5139, 0.4638,  ..., 0.3456, 0.4925, 0.4394],
#         [0.4568, 0.4219, 0.3565,  ..., 0.5904, 0.4990, 0.4342],
#         [0.4223, 0.4275, 0.4536,  ..., 0.3803, 0.5268, 0.3560],
#         ...,
#         [0.4563, 0.4161, 0.3285,  ..., 0.4848, 0.4895, 0.6121],
#         [0.4659, 0.4669, 0.3321,  ..., 0.4728, 0.5309, 0.6965],
#         [0.4419, 0.4308, 0.3438,  ..., 0.5243, 0.5146, 0.6128]],
#        device='cuda:0', grad_fn=<AddmmBackward>)

# %%
plt.plot(log_ps.cpu().data.numpy()[:,8])

# %%
error=abs(abs(test.values)-abs(log_ps.cpu().data.numpy()))
error
# Out:
# array([[0.01595371, 0.01270629, 0.02080528, ..., 0.04031071, 0.01621389,
#         0.01716839],
#        [0.01281208, 0.04926538, 0.00308875, ..., 0.00379851, 0.01875835,
#         0.01036979],
#        [0.00207437, 0.04810231, 0.02179325, ..., 0.07170612, 0.02680451,
#         0.0007471 ],
#        ...,
#        [0.0583715 , 0.05190178, 0.08543572, ..., 0.06033855, 0.03318893,
#         0.10741867],
#        [0.04962941, 0.01735735, 0.10245451, ..., 0.03956042, 0.00265533,
#         0.13866452],
#        [0.02943169, 0.02747467, 0.03229004, ..., 0.03398406, 0.01170675,
#         0.06053895]])

# %%
def metric_mse(X1,X2):
    X=abs(X1-X2)
    vector=[]
    for i in X:
        k=0
        c=0
        for j in range(X.shape[1]):
            k+=i[j]**2
        k=np.sqrt(k/X.shape[1])
        vector.append(k)
        c+=1
    
    return np.array(vector)

# %%
abs(test.values)[0]-abs(log_ps.cpu().data.numpy())[0]
# Out:
# array([-0.01595371,  0.01270629, -0.02080528, -0.00229045,  0.01112558,
#        -0.00643945, -0.01006478, -0.01618036,  0.01508494,  0.0233256 ,
#         0.03110787, -0.01313592, -0.0011929 ,  0.07628224,  0.00474717,
#        -0.04360362, -0.02240354,  0.01037467, -0.00645265,  0.03002688,
#         0.00938029,  0.04031071, -0.01621389, -0.01716839])

# %%
error1=pd.DataFrame(metric_mse(abs(test.values),abs(log_ps.cpu().data.numpy())), columns=['error'])
error1
# Out:
#           error
# 0      0.024885
# 1      0.026925
# 2      0.037016
# 3      0.029737
# 4      0.035520
# ...         ...
# 19995  0.064910
# 19996  0.054826
# 19997  0.079922
# 19998  0.066439
# 19999  0.040298
#
# [20000 rows x 1 columns]

# %%
error1['target']=target
error1
# Out:
#           error  target
# 0      0.024885       1
# 1      0.026925       1
# 2      0.037016       1
# 3      0.029737       1
# 4      0.035520       1
# ...         ...     ...
# 19995  0.064910       4
# 19996  0.054826       4
# 19997  0.079922       4
# 19998  0.066439       4
# 19999  0.040298       4
#
# [20000 rows x 2 columns]

# %%
result=error1

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
plt.figure(figsize=(30,10))
plt.style.use('classic')


plt.plot(result[result.target==1.0]['error'].values, color="blue", marker=".", markersize=1, linestyle='solid',linewidth=2,label='Healthy')
plt.plot(result[result.target==2.0]['error'].values, color="red", marker=".", markersize=1, linestyle='solid',linewidth=2,label='Replica')
plt.plot(result[result.target==3.0]['error'].values, color="green", marker=".", markersize=1, linestyle='solid',linewidth=2,label='Unlocked')
plt.plot(result[result.target==4]['error'].values, color="orange", marker=".", markersize=1, linestyle='solid',linewidth=2,label='Crack')

plt.tick_params(which='both', width=2, length=5)
#plt.gcf().autofmt_xdate()
#plt.tight_layout()
plt.legend(frameon=True)
plt.savefig("wt2_temp.pdf",bbox_inches='tight')

# %%
w1=np.concatenate((df_train_tensor,df_valid_tensor),axis=0)
w1 = torch.tensor(w1, dtype=torch.float)
w1=w1.cuda()
log_ps1 = model(w1)
log_ps1
# Out:
# tensor([[0.5302, 0.4580, 0.4719,  ..., 0.5470, 0.5457, 0.4904],
#         [0.4747, 0.4365, 0.4435,  ..., 0.4685, 0.5140, 0.5030],
#         [0.4864, 0.5069, 0.4485,  ..., 0.5670, 0.5263, 0.5110],
#         ...,
#         [0.5690, 0.5123, 0.5293,  ..., 0.5654, 0.5289, 0.4503],
#         [0.4993, 0.5143, 0.4976,  ..., 0.3679, 0.4227, 0.3813],
#         [0.5351, 0.4847, 0.4561,  ..., 0.6405, 0.5195, 0.5899]],
#        device='cuda:0', grad_fn=<AddmmBackward>)

# %%
ws=600
error_train=metric_mse(abs(np.concatenate((train.values,valid.values),axis=0)),abs(log_ps1.cpu().data.numpy()))
error_train=pd.Series(error_train).rolling(ws).mean()[ws-1:].values
mean=np.mean(error_train)
std=np.std(error_train)

# %%
np.max(error_train)
# Out:
# 0.06135463643271406

# %%
plt.figure(figsize=(10,7))
plt.style.use('classic')
plt.rcParams['font.size'] = '16'
#plt.plot(diferencia, label='diferencia')
#plt.plot(datatest1["target"], label='target')
p=len(result[result.target==1]['error'].rolling(ws).mean()[ws-1:].values)

#plt.plot(error_train, color="lime", marker=".", markersize=1, linestyle='solid',linewidth=2,label='Train')


plt.plot(result[result.target==1]['error'].rolling(ws).mean()[ws-1:].values, color="blue", marker=".", markersize=1, linestyle='solid',linewidth=2,label='Healthy')
plt.plot(result[result.target==2]['error'].rolling(ws).mean()[ws-1:].values, color="red", marker=".", markersize=1, linestyle='solid',linewidth=2,label='RB')
plt.plot(result[result.target==3]['error'].rolling(ws).mean()[ws-1:].values, color=[i/255 for i in (46, 134, 193)], marker=".", markersize=1, linestyle='solid',linewidth=2,label='UB')
plt.plot(result[result.target==4]['error'].rolling(ws).mean()[ws-1:].values, color=[i/255 for i in (125, 60, 152 )], marker=".", markersize=1, linestyle='solid',linewidth=2,label='CB')

plt.xlabel('Number of Samples', fontsize=16)
plt.ylabel('Averaged Prediction Error', fontsize=16)
plt.plot([mean+3*std]*p, color=[i/255 for i in (203, 67, 53 )], linestyle='--',linewidth=2,label='Max. tFD')
plt.plot([mean-3*std]*p, color=[i/255 for i in (203, 67, 53 )], linestyle='--',linewidth=2,label='Min. tFD')
#plt.plot([np.max(error_train)]*p, color="skyblue", linestyle='--',linewidth=2,label='Lower threshold')
plt.xlim(right=2080)
plt.tick_params(which='both', width=2, length=5)
#plt.gcf().autofmt_xdate()
#plt.tight_layout()
plt.legend(frameon=True,fontsize=14)
plt.savefig("J3RESULTS.pdf",bbox_inches='tight')

# %%
plt.figure(figsize=(10,7))
plt.style.use('classic')
plt.rcParams['font.size'] = '16'
#plt.plot(diferencia, label='diferencia')
#plt.plot(datatest1["target"], label='target')
p=len(result[result.target==1]['error'].rolling(ws).mean()[ws-1:].values)

#plt.plot(error_train, color="lime", marker=".", markersize=1, linestyle='solid',linewidth=2,label='Train')


plt.plot(result[result.target==1]['error'].rolling(ws).mean()[ws-1:].values, color="blue", marker=".", markersize=1, linestyle='solid',linewidth=2,label='Healthy')
plt.plot(result[result.target==2]['error'].rolling(ws).mean()[ws-1:].values, color="red", marker=".", markersize=1, linestyle='solid',linewidth=2,label='RB')
plt.plot(result[result.target==3]['error'].rolling(ws).mean()[ws-1:].values, color=[i/255 for i in (46, 134, 193)], marker=".", markersize=1, linestyle='solid',linewidth=2,label='UB')
plt.plot(result[result.target==4]['error'].rolling(ws).mean()[ws-1:].values, color=[i/255 for i in (125, 60, 152 )], marker=".", markersize=1, linestyle='solid',linewidth=2,label='CB')

plt.xlabel('Number of Samples', fontsize=16)
plt.ylabel('Averaged Prediction Error', fontsize=16)
plt.plot([mean+2*std]*p, color=[i/255 for i in (203, 67, 53 )], linestyle='--',linewidth=2,label='Max. tFD')
plt.plot([mean-2*std]*p, color=[i/255 for i in (203, 67, 53 )], linestyle='--',linewidth=2,label='Min. tFD')
#plt.plot([np.max(error_train)]*p, color="skyblue", linestyle='--',linewidth=2,label='Lower threshold')
plt.xlim(right=2080)
plt.tick_params(which='both', width=2, length=5)
#plt.gcf().autofmt_xdate()
#plt.tight_layout()
plt.legend(frameon=True,fontsize=14)
plt.savefig("J3RESULTS.pdf",bbox_inches='tight')

# %%
plt.figure(figsize=(10,7))
plt.style.use('classic')
plt.rcParams['font.size'] = '16'
#plt.plot(diferencia, label='diferencia')
#plt.plot(datatest1["target"], label='target')
p=len(result[result.target==1]['error'].rolling(ws).mean()[ws-1:].values)

#plt.plot(error_train, color="lime", marker=".", markersize=1, linestyle='solid',linewidth=2,label='Train')


plt.plot(result[result.target==1]['error'].rolling(ws).mean()[ws-1:].values, color="blue", marker=".", markersize=1, linestyle='solid',linewidth=2,label='Healthy')
plt.plot(result[result.target==2]['error'].rolling(ws).mean()[ws-1:].values, color="red", marker=".", markersize=1, linestyle='solid',linewidth=2,label='RB')
plt.plot(result[result.target==3]['error'].rolling(ws).mean()[ws-1:].values, color=[i/255 for i in (46, 134, 193)], marker=".", markersize=1, linestyle='solid',linewidth=2,label='UB')
plt.plot(result[result.target==4]['error'].rolling(ws).mean()[ws-1:].values, color=[i/255 for i in (125, 60, 152 )], marker=".", markersize=1, linestyle='solid',linewidth=2,label='CB')

plt.xlabel('Number of Samples', fontsize=16)
plt.ylabel('Averaged Prediction Error', fontsize=16)
plt.plot([mean+std]*p, color=[i/255 for i in (203, 67, 53 )], linestyle='--',linewidth=2,label='Max. tFD')
plt.plot([mean-std]*p, color=[i/255 for i in (203, 67, 53 )], linestyle='--',linewidth=2,label='Min. tFD')
#plt.plot([np.max(error_train)]*p, color="skyblue", linestyle='--',linewidth=2,label='Lower threshold')
plt.xlim(right=2080)
plt.tick_params(which='both', width=2, length=5)
#plt.gcf().autofmt_xdate()
#plt.tight_layout()
plt.legend(frameon=True,fontsize=14)
plt.savefig("J3RESULTS.pdf",bbox_inches='tight')
